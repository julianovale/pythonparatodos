# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/pythonparatodos/blob/main/M%C3%B3dulo10Aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/kelvins/Municipios-Brasileiros/main/csv/municipios.csv'
df = pd.read_csv(url)
df
# Out:
#       codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0         5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1         3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2         5200100            Abadiânia -16.19700   -48.7057        0         52
# 3         3100203               Abaeté -19.15510   -45.4444        0         31
# 4         1500107           Abaetetuba  -1.72183   -48.8788        0         15
# ...           ...                  ...       ...        ...      ...        ...
# 5565      2933604          Xique-Xique -10.82300   -42.7245        0         29
# 5566      2517407               Zabelê  -8.07901   -37.1057        0         25
# 5567      3557154             Zacarias -21.05060   -50.0552        0         35
# 5568      2114007              Zé Doca  -3.27014   -45.6553        0         21
# 5569      4219853               Zortéa -27.45210   -51.5520        0         42
#
# ...

# %%
print(df.columns.ravel())
# Out:
# ['codigo_ibge' 'nome' 'latitude' 'longitude' 'capital' 'codigo_uf']

# %%
sp = df.loc[df['codigo_uf']==35]
sp
# Out:
#       codigo_ibge                  nome  ...  capital  codigo_uf
# 30        3500105            Adamantina  ...        0         35
# 32        3500204                Adolfo  ...        0         35
# 62        3500303                 Aguaí  ...        0         35
# 65        3500402        Águas da Prata  ...        0         35
# 67        3500501      Águas de Lindóia  ...        0         35
# ...           ...                   ...  ...      ...        ...
# 5528      3556909  Vista Alegre do Alto  ...        0         35
# 5534      3556958        Vitória Brasil  ...        0         35
# 5545      3557006            Votorantim  ...        0         35
# 5546      3557105           Votuporanga  ...        0         35
# 5567      3557154              Zacarias  ...        0         35
#
# [645 rows x 6 columns]

# %%
df3 = df.loc[df['codigo_uf']==35, ['nome', 'latitude','longitude']]
df3
# Out:
#                       nome  latitude  longitude
# 30              Adamantina  -21.6820   -51.0737
# 32                  Adolfo  -21.2325   -49.6451
# 62                   Aguaí  -22.0572   -46.9735
# 65          Águas da Prata  -21.9319   -46.7176
# 67        Águas de Lindóia  -22.4733   -46.6314
# ...                    ...       ...        ...
# 5528  Vista Alegre do Alto  -21.1692   -48.6284
# 5534        Vitória Brasil  -20.1956   -50.4875
# 5545            Votorantim  -23.5446   -47.4388
# 5546           Votuporanga  -20.4237   -49.9781
# 5567              Zacarias  -21.0506   -50.0552
#
# [645 rows x 3 columns]

# %%
df3.reset_index(inplace=True)
df3.drop(['index'], axis=1, inplace=True)
df3
# Out:
#                      nome  latitude  longitude
# 0              Adamantina  -21.6820   -51.0737
# 1                  Adolfo  -21.2325   -49.6451
# 2                   Aguaí  -22.0572   -46.9735
# 3          Águas da Prata  -21.9319   -46.7176
# 4        Águas de Lindóia  -22.4733   -46.6314
# ..                    ...       ...        ...
# 640  Vista Alegre do Alto  -21.1692   -48.6284
# 641        Vitória Brasil  -20.1956   -50.4875
# 642            Votorantim  -23.5446   -47.4388
# 643           Votuporanga  -20.4237   -49.9781
# 644              Zacarias  -21.0506   -50.0552
#
# [645 rows x 3 columns]

# %%
import folium

# %%
map = folium.Map(location=[-22.7864889,-50.6786708], zoom_start = 7) # parâmetros iniciais de visualização do mapa
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
for i in range(0,len(df3)):
  pop = str(df3.iloc[i]['nome'])
  pop = pop.encode('latin1')
  folium.Marker([df3.iloc[i]['latitude'],df3.iloc[i]['longitude']],popup=pop).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
map = folium.Map(location=[-22.7864889,-50.6786708], zoom_start = 7, tiles = 'cartodbdark_matter') # parâmetros iniciais de visualização do mapa
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
from folium.plugins import MarkerCluster

# %%
mc = MarkerCluster()

for i in range(0,len(df3)):
  pop = str(df3.iloc[i]['nome'])
  pop = pop.encode('latin1')
  #folium.Marker([df3.iloc[i]['latitude'],df3.iloc[i]['longitude']],popup=pop).add_to(map)
  mc.add_child(folium.CircleMarker([df3.iloc[i]['latitude'],df3.iloc[i]['longitude']], radius = 5, popup=pop, color='blue', fill = True, fill_color='yellow'))

mc.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
map = folium.Map(location=[-22.7864889,-50.6786708], zoom_start = 7, tiles = 'OpenStreetMap')

fg1 = folium.FeatureGroup(name = 'Municípios A')
fg2 = folium.FeatureGroup(name = 'Municípios B')
fg3 = folium.FeatureGroup(name = 'Municípios C')

for i in range(0,len(df3)):
  pop = str(df3.iloc[i]['nome'])
  pop = pop.encode('latin1')
  if i <= 200:
    fg1.add_child(folium.CircleMarker([df3.iloc[i]['latitude'],df3.iloc[i]['longitude']], radius = 5, popup=pop, color='red', fill = True, fill_color='red'))
  elif i <= 400:
    fg2.add_child(folium.CircleMarker([df3.iloc[i]['latitude'],df3.iloc[i]['longitude']], radius = 5, popup=pop, color='yellow', fill = True, fill_color='yellow'))
  else:
    fg3.add_child(folium.CircleMarker([df3.iloc[i]['latitude'],df3.iloc[i]['longitude']], radius = 5, popup=pop, color='blue', fill = True, fill_color='blue'))


map.add_child(fg1)
map.add_child(fg2)
map.add_child(fg3)
map.add_child(folium.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
