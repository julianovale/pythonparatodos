# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/pythonparatodos/blob/main/M%C3%B3dulo03Aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = [4,3,2,1,5]
y = [10,7,8,4,3]
plt.plot(x,y,"b--")
plt.show()

# %%
x = [4,3,2,1,5]
y = [10,7,8,4,3]
plt.plot(x,y,"m--")
plt.show()

# %%
x = [4,3,2,1,5]
y = [10,7,8,4,3]
plt.plot(x,y,"b-.")
plt.scatter(x,y,marker='*',color='red')
plt.show()

# %%
x = [4,3,2,1,5]
y = [10,7,8,4,3]
plt.plot(x,y,"b-.")
plt.scatter(x,y,marker='o',color='red')
plt.show()

# %%
# ?plt.scatter
