# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/pythonparatodos/blob/main/M%C3%B3dulo03Aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6]
y = [1,4,9,16,25,36]
plt.plot(x,y,color='blue')
plt.scatter(x,y,color='red')
plt.title('Dados de demanda')
plt.xlabel("dia")
plt.ylabel('demanda')
plt.grid()
plt.legend(['Estimativa','Dado'])
plt.show()
