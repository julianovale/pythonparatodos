# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/pythonparatodos/blob/main/M%C3%B3dulo09Aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

header = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0',
    'X-Requested-With': 'XMLHttpRequest'
}

def readDataYield(name):
  print('Leitura dos dados da empresa '+name)
  filename = base_url+str(name)
  r = requests.get(filename, headers=header)
  dt = pd.read_html(r.text)

  yi = 0
  if (len(dt) > 1):
    tab = dt[2]
    m,n = tab.shape
    if (m > 7):
      if (n > 2):
        yi = tab.iloc[8,3]
      else:
        print('Faltou dado!')
    else:
      print('Faltou dado!')
  else:
    print('Faltou dado!')
  return yi

# %%
# Leituras dos tickers das empresas
url = 'http://fundamentus.com.br/detalhes.php?papel='
r = requests.get(url, headers=header)
d = pd.read_html(r.text)
d
df = d[0]

base_url = 'http://fundamentus.com.br/detalhes.php?papel='
name = list(df['Papel'])
comercial = list(df['Nome Comercial'])

# %%
dk = pd.DataFrame(columns=['Nome', 'Sigla', 'Dividend Yield'])

for i in range(0,len(name)):
  yi = readDataYield(name[i])
  dk.loc[i] = [comercial[i], name[i], yi]
dk
# Out:
# Leitura dos dados da empresa AALR3
# Leitura dos dados da empresa ABCB3
# Leitura dos dados da empresa ABCB4
# Leitura dos dados da empresa ABEV3
# Leitura dos dados da empresa ABRE3
# Faltou dado!
# Leitura dos dados da empresa ABYA3
# Leitura dos dados da empresa ACES3
# Leitura dos dados da empresa ACES4
# Leitura dos dados da empresa ADHM3
# Leitura dos dados da empresa AEDU11
# Leitura dos dados da empresa AEDU3
# Leitura dos dados da empresa AELP3
# Leitura dos dados da empresa AERI3
# Leitura dos dados da empresa AESL3
# Leitura dos dados da empresa AESL4
# Leitura dos dados da empresa AFLT3
# Leitura dos dados da empresa AFLU3
# Leitura dos dados da empresa AFLU5
# Leitura dos dados da empresa AGEI3
# Leitura dos dados da empresa AGEN33
# Leitura dos dados da empresa AGIN3
# Leitura dos dados da empresa AGRO3
# Leitura dos dados da empresa AHEB3
# Leitura dos dados da empresa AHEB5
# Leitura dos dados da empresa AHEB6
# Leitura dos dados da empresa ALBA3
# ...

# %%
dts = dk.astype(str)
dts['Dividend Yield'] = dts['Dividend Yield'].str.replace('%',"")
dts['Dividend Yield'] = dts['Dividend Yield'].str.replace('.',"")
dts['Dividend Yield'] = dts['Dividend Yield'].str.replace(',',".")
dts['Dividend Yield'] = dts['Dividend Yield'].astype(float)
dts.sort_values(by=['Dividend Yield'], inplace=True, ascending=False)
dts.head(30)
# Out:
#                                          Nome   Sigla  Dividend Yield
# 885                                TARPON INV   TRPN3           104.7
# 574                         MINASMÁQUINAS S/A   MMAQ4            79.8
# 639    CIA. DE PARTICIPAÇÕES ALIANÇA DA BAHIA   PEAB3            56.8
# 262                                       CR2   CRDE3            54.0
# 640    CIA. DE PARTICIPAÇÕES ALIANÇA DA BAHIA   PEAB4            50.6
# 138                                 Patagonia  BPAT33            35.7
# 277                                 COPASA MG   CSMG3            18.0
# 946                            WHIRLPOOL S.A.   WHRL4            16.9
# 945                            WHIRLPOOL S.A.   WHRL3            16.7
# 898                                   UNICASA   UCAS3            15.3
# 728                                      ROMI   ROMI3            13.9
# 362                                      EMAE   EMAE4            12.6
# ...
